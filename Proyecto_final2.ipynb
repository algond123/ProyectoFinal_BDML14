# %%
import pandas as pd

# Cargar el dataset
df_artist = pd.read_csv('./Spotify Dataset 1921-2020/artists.csv')
df_tracks = pd.read_csv('./Spotify Dataset 1921-2020/tracks.csv')
print(f'{df_artist.head()}\n')
print(f'{df_tracks.head()}\n')
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0
#
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# ...

# %%
print('Informacion de df_artist:')
print(df_artist.shape)
print(f'{df_artist.info()}\n\n')
print('Informacion de df_tracks:')
print(df_tracks.shape)
print(f'{df_tracks.info()}\n\n')
# Out:
# Informacion de df_artist:
# (1162095, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1162095 entries, 0 to 1162094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1162095 non-null  object
#  1   followers   1162084 non-null  float64
#  2   genres      1162095 non-null  object
#  3   name        1162092 non-null  object
#  4   popularity  1162095 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 44.3+ MB
# None
#
#
# Informacion de df_tracks:
# (586672, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
# ...

# %%
# Realizamos una unión (merge) de los DataFrames df_tracks y df_artist
# utilizando las columnas "id", "name" y "popularity" como claves comunes,
# manteniendo todas las filas de df_tracks (left join).
merged_data = df_tracks.merge(df_artist, how="left", on=["id","name", "popularity"])

# %%
nul_df_artist = df_artist.isna().sum()
nul_df_tracks = df_tracks.isna().sum()
nul_merged_data = merged_data.isna().sum()

print(f'Vacios de artist {df_artist.shape}:\n{nul_df_artist}\n\n\
Vacios de tracks{df_tracks.shape}:\n{nul_df_tracks}\n\n\
Vacios del merge{merged_data.shape}:\n{nul_merged_data}')
# Out:
# Vacios de artist (1162095, 5):
# id             0
# followers     11
# genres         0
# name           3
# popularity     0
# dtype: int64
#
# Vacios de tracks(586672, 20):
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64
#
# Vacios del merge(586672, 22):
# id                       0
# name                    71
# popularity               0
# duration_ms              0
# explicit                 0
# artists                  0
# id_artists               0
# release_date             0
# danceability             0
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
# Imprimir las columnas de df_artist
print("Columnas de df_artist:")
print(df_artist.columns)

# Imprimir las columnas de df_tracks
print("\nColumnas de df_tracks:")
print(df_tracks.columns)

# Imprimir las columnas de merged_data
print("\nColumnas de merged_data:")
print(merged_data.columns)
# Out:
# Columnas de df_artist:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')
#
# Columnas de df_tracks:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')
#
# Columnas de merged_data:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers',
#        'genres'],
#       dtype='object')

# %%
# Imprimir las columnas de merged_data
print("\nColumnas de merged_data:")
print(merged_data.columns)
# Out:
# Columnas de merged_data:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers',
#        'genres'],
#       dtype='object')

# %%
merged_data_clean = merged_data.drop(columns=['name', 'id', 'time_signature', 'id_artists', 'release_date', 'followers', 'genres'])
merged_data_clean.to_csv('./merged_data_clean.csv')

# %%
merged_data_clean.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
merged_data_clean.hist(bins= 40, figsize= (18 , 16))
# Out:
# array([[<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'duration_ms'}>,
#         <Axes: title={'center': 'explicit'}>,
#         <Axes: title={'center': 'danceability'}>],
#        [<Axes: title={'center': 'energy'}>,
#         <Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'mode'}>],
#        [<Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>,
#         <Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>],
#        [<Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


# Compute the correlation matrix
corr = np.abs(merged_data_clean.drop(['artists'], axis=1).corr())
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5,
            linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})

plt.show()

# %%
corr.describe()
# Out:
#        popularity  duration_ms   explicit  danceability     energy        key  \
# count   14.000000    14.000000  14.000000     14.000000  14.000000  14.000000
# mean     0.206015     0.117731   0.146664      0.239815   0.303558   0.093533
# std      0.261550     0.259333   0.254243      0.253052   0.307087   0.262874
# min      0.004643     0.000337   0.005745      0.018824   0.024825   0.001035
# 25%      0.037080     0.007656   0.016591      0.109719   0.079703   0.006774
# 50%      0.129182     0.027645   0.084889      0.193155   0.212969   0.017061
# 75%      0.285858     0.107598   0.145414      0.242604   0.354786   0.027337
# max      1.000000     1.000000   1.000000      1.000000   1.000000   1.000000
#
#         loudness       mode  speechiness  acousticness  instrumentalness  \
# count  14.000000  14.000000    14.000000     14.000000         14.000000
# mean    0.289701   0.107587     0.159021      0.271631          0.194108
# ...

# %%
merged_data_clean.isna().sum()
# Out:
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# dtype: int64

# %%
final_df_noEncode = merged_data_clean.drop(columns=['artists'])

# %%
final_df_noEncode.head()
# Out:
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           6       126903         0         0.645  0.4450    0   -13.338
# 1           0        98200         0         0.695  0.2630    0   -22.136
# 2           0       181640         0         0.434  0.1770    1   -21.180
# 3           0       176907         0         0.321  0.0946    7   -27.961
# 4           0       163080         0         0.402  0.1580    3   -16.900
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.4510         0.674            0.7440     0.151    0.127
# 1     1       0.9570         0.797            0.0000     0.148    0.655
# 2     1       0.0512         0.994            0.0218     0.212    0.457
# 3     1       0.0504         0.995            0.9180     0.104    0.397
# 4     0       0.0390         0.989            0.1300     0.311    0.196
#
#      tempo
# 0  104.851
# 1  102.009
# 2  130.418
# 3  169.980
# 4  103.220

# %%
final_df_noEncode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   popularity        586672 non-null  int64
#  1   duration_ms       586672 non-null  int64
#  2   explicit          586672 non-null  int64
#  3   danceability      586672 non-null  float64
#  4   energy            586672 non-null  float64
#  5   key               586672 non-null  int64
#  6   loudness          586672 non-null  float64
#  7   mode              586672 non-null  int64
#  8   speechiness       586672 non-null  float64
#  9   acousticness      586672 non-null  float64
#  10  instrumentalness  586672 non-null  float64
#  11  liveness          586672 non-null  float64
#  12  valence           586672 non-null  float64
#  13  tempo             586672 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 62.7 MB

# %%
# Asegúrate de que final_df_noEncode es un DataFrame de pandas
# Reordenar las columnas para que 'popularity' esté en la primera posición
cols = ['popularity'] + [col for col in final_df_noEncode.columns if col != 'popularity']
final_df_noEncode = final_df_noEncode[cols]

# Ahora final_df_noEncode tiene la columna 'popularity' en la primera posición

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
x = final_df_noEncode.drop(columns=['popularity'])
y = final_df_noEncode[['popularity']]

# Division previa antes de encontrar los outliers
# x_train, x_test, y_train, y_test = train_test_split(x , y, test_size=0.2, random_state=42)

# %%
final_df_noEncode.head()
# Out:
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           6       126903         0         0.645  0.4450    0   -13.338
# 1           0        98200         0         0.695  0.2630    0   -22.136
# 2           0       181640         0         0.434  0.1770    1   -21.180
# 3           0       176907         0         0.321  0.0946    7   -27.961
# 4           0       163080         0         0.402  0.1580    3   -16.900
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.4510         0.674            0.7440     0.151    0.127
# 1     1       0.9570         0.797            0.0000     0.148    0.655
# 2     1       0.0512         0.994            0.0218     0.212    0.457
# 3     1       0.0504         0.995            0.9180     0.104    0.397
# 4     0       0.0390         0.989            0.1300     0.311    0.196
#
#      tempo
# 0  104.851
# 1  102.009
# 2  130.418
# 3  169.980
# 4  103.220

# %%
final_df_noEncode.hist(column='popularity', bins=100)
# Out:
# array([[<Axes: title={'center': 'popularity'}>]], dtype=object)

# %%
# Filtrar el DataFrame para mantener solo los valores de 'popularity' entre 2 y 82
final_df_noEncode = final_df_noEncode[(final_df_noEncode['popularity'] >= 2) & (final_df_noEncode['popularity'] <= 82)]
final_df_noEncode.to_csv('./final_df_noEncode.csv')

# %%
final_df_noEncode.hist(column='popularity', bins=100)
# Out:
# array([[<Axes: title={'center': 'popularity'}>]], dtype=object)

# %%
final_df_noEncode.head()
# Out:
#      popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0             6       126903         0         0.645  0.4450    0   -13.338
# 26            4       180800         0         0.420  0.2880    7   -14.005
# 149          41       177133         0         0.614  0.0423    4   -12.033
# 150          38       161933         0         0.831  0.2620    8   -12.386
# 151          30       206600         0         0.537  0.0443    3   -16.474
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       1       0.4510         0.674          0.744000     0.151    0.127
# 26      1       0.0701         0.994          0.000216     0.196    0.400
# 149     1       0.0535         0.996          0.002930     0.183    0.211
# 150     1       0.0942         0.984          0.912000     0.204    0.901
# 151     0       0.0343         0.996          0.000265     0.152    0.137
#
#        tempo
# 0    104.851
# 26   139.575
# 149   89.822
# ...

# %%
############################################################
# Para poder continuar sin correr todo lo anterior de nuevo.
############################################################

import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

final_df_noEncode = pd.read_csv('./final_df_noEncode.csv')
x = final_df_noEncode.drop(columns=['popularity'])
y = final_df_noEncode[['popularity']]

# %%
final_df_noEncode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 529516 entries, 0 to 586671
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   popularity        529516 non-null  int64
#  1   duration_ms       529516 non-null  int64
#  2   explicit          529516 non-null  int64
#  3   danceability      529516 non-null  float64
#  4   energy            529516 non-null  float64
#  5   key               529516 non-null  int64
#  6   loudness          529516 non-null  float64
#  7   mode              529516 non-null  int64
#  8   speechiness       529516 non-null  float64
#  9   acousticness      529516 non-null  float64
#  10  instrumentalness  529516 non-null  float64
#  11  liveness          529516 non-null  float64
#  12  valence           529516 non-null  float64
#  13  tempo             529516 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 60.6 MB

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

alpha_vector = np.logspace(-1,10,20)
#maxDepth = range(1, 11)
param_grid = {'alpha': alpha_vector}

grid = GridSearchCV(Lasso(), scoring= 'neg_mean_squared_error', param_grid=param_grid, cv = 6, return_train_score =True, verbose=2)
grid.fit(x_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

#-1 porque es negado
scores = -1*np.array(grid.cv_results_['mean_test_score'])
plt.semilogx(alpha_vector,scores,'-o')
plt.xlabel('alpha',fontsize=16)
plt.ylabel('3-Fold MSE')
plt.show()
# Out:
# Fitting 6 folds for each of 20 candidates, totalling 120 fits
# [CV] END ..........................................alpha=0.1; total time=   0.1s
# [CV] END ..........................................alpha=0.1; total time=   0.1s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.37926901907322497; total time=   0.0s
# [CV] END ..........................alpha=0.37926901907322497; total time=   0.0s
# [CV] END ..........................alpha=0.37926901907322497; total time=   0.0s
# [CV] END ..........................alpha=0.37926901907322497; total time=   0.0s
# [CV] END ..........................alpha=0.37926901907322497; total time=   0.0s
# ...

# %%
grid.best_params_['alpha']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 grid.best_params_['alpha']
#
# NameError: name 'grid' is not defined

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.linear_model import Lasso
import numpy as np

tscv = TimeSeriesSplit(n_splits=3)

alpha_vector = np.logspace(-4,4,20)
param_grid = {'alpha': alpha_vector}

grid = GridSearchCV(Lasso(), param_grid=param_grid, cv = tscv.split(x_train), scoring="neg_mean_squared_error").fit(x_train, y_train)

# %%
print("best parameters: {}".format(grid.best_params_))

scores = -grid.cv_results_['mean_test_score']
std_scores = grid.cv_results_['std_test_score']
plt.errorbar(np.log10(alpha_vector),scores,yerr=std_scores, fmt='o-',ecolor='g')
plt.xlabel('log(alpha)',fontsize=16)
plt.ylabel('CV MSE')
plt.grid()
plt.show()
# Out:
# best parameters: {'alpha': 0.0001}

# %%
features = final_df_noEncode.columns.drop(['popularity'])

# %%
from sklearn.metrics import mean_squared_error

alpha_optimo = grid.best_params_['alpha']
lasso = Lasso(alpha = alpha_optimo).fit(x_train,y_train)

ytrainLasso = lasso.predict(x_train)
ytestLasso  = lasso.predict(x_test)

mseTrainModelLasso = mean_squared_error(y_train,ytrainLasso)
mseTestModelLasso = mean_squared_error(y_test,ytestLasso)

print('MSE Modelo Lasso (train): %0.3g' % mseTrainModelLasso)
print('MSE Modelo Lasso (test) : %0.3g' % mseTestModelLasso)
print('RMSE Modelo Lasso (train): %0.3g' % np.sqrt(mseTrainModelLasso))
print('RMSE Modelo Lasso (test) : %0.3g' % np.sqrt(mseTestModelLasso))
w = lasso.coef_
for f,wi in zip(features,w):
    print(f,wi)
# Out:
# MSE Modelo Lasso (train): 232
# MSE Modelo Lasso (test) : 232
# RMSE Modelo Lasso (train): 15.2
# RMSE Modelo Lasso (test) : 15.2
# duration_ms 2.400402212417208e-06
# explicit 10.75902220149748
# danceability 17.156296415846025
# energy -0.8586104105402589
# key 0.024714481159842084
# loudness 0.6442572121195651
# mode 0.15747248879155148
# speechiness -0.799052919621857
# acousticness -8.764131931075775
# instrumentalness -3.8027078970941854
# liveness -3.5667424245014487
# valence -12.940944342775614
# tempo 0.010663442931595588

# %%
pip install utils
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

from utils import plot_decision_boundary, poly_linear_regression, CM_BRIGHT

# creamos el modelo y ajustamos
neighbors = range(1,16)
acc_train = []
acc_test  = []

for n in neighbors:
    knn = KNeighborsClassifier(n_neighbors=n).fit(x_train, y_train)    
    acc_train.append(knn.score(x_train, y_train))
    acc_test.append(knn.score(x_test, y_test))

plt.plot(neighbors,acc_train,'b',label='train')
plt.plot(neighbors,acc_test,'r',label='test')
plt.legend()
plt.xlabel('# vecinos')
plt.ylabel('ACC')
plt.show()
# Out:
# c:\Users\Alejandro Catalan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\Alejandro Catalan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\Alejandro Catalan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
final_df_noEncode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 529516 entries, 0 to 586671
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   popularity        529516 non-null  int64
#  1   duration_ms       529516 non-null  int64
#  2   explicit          529516 non-null  int64
#  3   danceability      529516 non-null  float64
#  4   energy            529516 non-null  float64
#  5   key               529516 non-null  int64
#  6   loudness          529516 non-null  float64
#  7   mode              529516 non-null  int64
#  8   speechiness       529516 non-null  float64
#  9   acousticness      529516 non-null  float64
#  10  instrumentalness  529516 non-null  float64
#  11  liveness          529516 non-null  float64
#  12  valence           529516 non-null  float64
#  13  tempo             529516 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 60.6 MB

# %%
final_df_noEncode.columns
# Out:
# Index(['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
pip install torch

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch

# Cargar dataset
df = final_df_noEncode

# Seleccionar características musicales relevantes
features = ['popularity', 'duration_ms', 'explicit',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
X = df[features]

# Normalizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convertir a tensor de PyTorch
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)

# %%
import torch.nn as nn

class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim=8):
        super(Autoencoder, self).__init__()
        
        # Codificador
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            nn.Linear(16, latent_dim)
        )
        
        # Decodificador
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 16),
            nn.ReLU(),
            nn.Linear(16, input_dim)
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Definir modelo
input_dim = X_tensor.shape[1]
autoencoder = Autoencoder(input_dim)

# %%
import torch.optim as optim

# Definir función de pérdida y optimizador
criterion = nn.MSELoss()
optimizer = optim.Adam(autoencoder.parameters(), lr=0.01)

# Entrenamiento
epochs = 400
for epoch in range(epochs):
    optimizer.zero_grad()
    output = autoencoder(X_tensor)
    loss = criterion(output, X_tensor)
    loss.backward()
    optimizer.step()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0, Loss: 0.2086
# Epoch 10, Loss: 0.1916
# Epoch 20, Loss: 0.1756
# Epoch 30, Loss: 0.1643
# Epoch 40, Loss: 0.1545
# Epoch 50, Loss: 0.1452
# Epoch 60, Loss: 0.1366
# Epoch 70, Loss: 0.1295
# Epoch 80, Loss: 0.1239
# Epoch 90, Loss: 0.1197
# Epoch 100, Loss: 0.1169
# Epoch 110, Loss: 0.1151
# Epoch 120, Loss: 0.1125
# Epoch 130, Loss: 0.1109
# Epoch 140, Loss: 0.1094
# Epoch 150, Loss: 0.1081
# Epoch 160, Loss: 0.1069
# Epoch 170, Loss: 0.1098
# Epoch 180, Loss: 0.1051
# Epoch 190, Loss: 0.1045
# Epoch 200, Loss: 0.1038
# Epoch 210, Loss: 0.1031
# Epoch 220, Loss: 0.1023
# Epoch 230, Loss: 0.1016
# Epoch 240, Loss: 0.1001
# Epoch 250, Loss: 0.0992
# Epoch 260, Loss: 0.1005
# Epoch 270, Loss: 0.0992
# Epoch 280, Loss: 0.0966
# Epoch 290, Loss: 0.0952
# Epoch 300, Loss: 0.0939
# Epoch 310, Loss: 0.0931
# Epoch 320, Loss: 0.0960
# Epoch 330, Loss: 0.0910
# Epoch 340, Loss: 0.0899
# Epoch 350, Loss: 0.0895
# Epoch 360, Loss: 0.0891
# Epoch 370, Loss: 0.0871
# ...

# %%
# Obtener la representación latente de las canciones
with torch.no_grad():
    latent_representations = autoencoder.encoder(X_tensor).numpy()

# %%
from sklearn.cluster import KMeans

# Aplicar K-Means a las representaciones latentes
num_clusters = 6
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
clusters = kmeans.fit_predict(latent_representations)

# Agregar los clusters al DataFrame
df["mood"] = clusters

# Mostrar distribución de clusters
print(df["mood"].value_counts())
# Out:
# mood
# 1    170918
# 4    154738
# 0    111540
# 2     36066
# 5     31267
# 3     24987
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'mood'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reducir dimensiones con PCA
pca = PCA(n_components=2)
latent_2d = pca.fit_transform(latent_representations)

# Graficar Clusters
plt.figure(figsize=(8, 6))
for i in range(num_clusters):
    plt.scatter(latent_2d[clusters == i, 0], latent_2d[clusters == i, 1], label=f"Mood {i}")

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("Mood de Canciones")
plt.legend()
plt.show()

# %%
# Agrupar por Mood y calcular la media de las características
cluster_summary = df.groupby("mood")[features].mean()

# Mostrar las características principales de cada Mood
print("📌 Características principales de cada Mood:")
print(cluster_summary)

import seaborn as sns
import matplotlib.pyplot as plt

# Configurar tamaño del gráfico
plt.figure(figsize=(12, 6))

# Crear un gráfico de barras para comparar características por Mood
sns.heatmap(cluster_summary.T, cmap="coolwarm", annot=True, fmt=".2f")

plt.title("Características Promedio por Mood")
plt.xlabel("Mood")
plt.ylabel("Característica")
plt.show()
# Out:
# 📌 Características principales de cada Mood:
#       popularity    duration_ms  explicit  danceability    energy       key  \
# mood
# 0      45.470602  221061.403156  0.000000      0.632268  0.641894  5.122691
# 1      29.989434  235677.221141  0.000000      0.570933  0.574823  5.845833
# 2      27.874452  210608.962929  0.000000      0.535188  0.571452  4.388621
# 3      46.734102  218263.808540  1.000000      0.681725  0.686651  5.410974
# 4      19.842153  233914.402054  0.000032      0.532414  0.498500  4.885794
# 5      21.868679  251560.836441  0.000000      0.443858  0.389131  4.704033
#
#        loudness      mode  speechiness  acousticness  instrumentalness  \
# mood
# 0     -7.751291  1.000000     0.065982      0.300565          0.018324
# 1     -9.809152  0.000000     0.099945      0.405533          0.100275
# 2    -10.774901  0.999556     0.287059      0.503307          0.020388
# 3     -6.979724  0.543763     0.189997      0.207112          0.026918
# ...

# %%
## Guardar la division
cluster_summary.to_csv('./cluster_summary.csv')

# %%
merged_clustered = merged_data_clean.merge(df, how="left", on=['popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo'])

# Filtrar el DataFrame para mantener solo los valores de 'popularity' entre 2 y 82
merged_clustered = merged_clustered[(merged_clustered['popularity'] >= 2) & (merged_clustered['popularity'] <= 82)]
merged_clustered.to_csv('./merged_clustered.csv')

# %%
merged_clustered.head()
# Out:
#      popularity  duration_ms  explicit                            artists  \
# 0             6       126903         0                            ['Uli']
# 26            4       180800         0                    ['Louis Lynel']
# 149          41       177133         0                   ['Bessie Smith']
# 150          38       161933         0  ['Louis Armstrong', 'Earl Hines']
# 151          30       206600         0                   ['Bessie Smith']
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.645  0.4450    0   -13.338     1       0.4510         0.674
# 26          0.420  0.2880    7   -14.005     1       0.0701         0.994
# 149         0.614  0.0423    4   -12.033     1       0.0535         0.996
# 150         0.831  0.2620    8   -12.386     1       0.0942         0.984
# 151         0.537  0.0443    3   -16.474     0       0.0343         0.996
#
#      instrumentalness  liveness  valence    tempo  mood
# ...

# %%
final_df_noEncode.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  529516.000000  5.295160e+05  529516.000000  529516.000000
# mean       30.451758  2.304921e+05       0.047198       0.567886
# std        16.810635  1.161040e+05       0.212062       0.164073
# min         2.000000  1.470800e+04       0.000000       0.000000
# 25%        17.000000  1.775942e+05       0.000000       0.459000
# 50%        30.000000  2.184670e+05       0.000000       0.581000
# 75%        42.000000  2.655070e+05       0.000000       0.688000
# max        82.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  529516.000000  529516.000000  529516.000000  529516.000000
# mean        0.560730       5.225765      -9.891741       0.655567
# std         0.244842       3.522353       4.867405       0.475184
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %% [markdown]
# 0. Fiestero 🎉🔥 (Energy, Danceability, Valence) → Para quienes están llenos de emoción y ganas de celebrar.
# 1. Alegre ❤️🎶 (Energy, Valence, Liveness) → Aquellos que sienten todo con intensidad y buscan experiencias profundas.
# 2. Relajados 🌊☕ (Acousticness, Danceability, Valence) → Para quienes disfrutan la calma y el equilibrio.
# 3. Reflexivos 🎧🌿 (Acousticness, Speechiness, Liveness) → Personas que disfrutan momentos de introspección y tranquilidad.
# 4. Triste 🗣️🎤 (Speechiness, Liveness, Loudness) → Personas comunicativas, auténticas y con una fuerte personalidad.
# 5. Dinámicos 🚀🎵 (Danceability, Energy, Loudness) → Para quienes siempre están en movimiento y buscan adrenalina.

# %% [markdown]
# # Distintos modelos de clasificacion

# %% [markdown]
# ## Randon Forest

# %%
# Randon Forest

# %% [markdown]
# ## Knn

# %%
# Knn

# %% [markdown]
# ## Regresion logistica

# %%
# Regresion logistica
